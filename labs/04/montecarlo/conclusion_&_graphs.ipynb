# %% [markdown]
# # Calculating Pi (π) With Monte Carlo Using Parallel Computing
#
# Oswaldo Hernández A01274570

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
threads = np.array(['1', '2', '4', '8', '16'])
time = np.array([
    0.000299,
    0.040916,
    0.118902,
    0.235138,
    0.306767
])
abs_error = np.array([
    0.0100473,
    0.00632735,
    0.00744735,
    0.00888735,
    0.00940735
])

# %%
plt.plot(threads, time, color='red', marker='o')
plt.title("Elapsed time vs # of threads")
plt.xlabel("# threads")
plt.ylabel("Time(s)")
plt.grid()
plt.show()

# %% [markdown]
# More numbers of threads needs more runtime but I believe this due to creating the pthreads. We have to cycles that iterate through the pthreads ID array. It is probable that the generation of dots is faster with more threads but creating the threads is costly.
